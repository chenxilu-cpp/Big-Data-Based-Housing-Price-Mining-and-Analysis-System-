# %%
import pandas as pd
from pyecharts.globals import CurrentConfig, NotebookType
CurrentConfig.NOTEBOOK_TYPE = NotebookType.JUPYTER_NOTEBOOK

# %%
df = pd.read_csv('data.csv')
df.head()
house_type = df['户型'].value_counts().index.to_list()
house_num = df['户型'].value_counts().to_list()
import pandas as pd
from pyecharts.charts import Pie, Line, Bar
from pyecharts import options as opts

from pyecharts.globals import CurrentConfig, NotebookType

# 设置 Jupyter Notebook 环境
CurrentConfig.NOTEBOOK_TYPE = NotebookType.JUPYTER_NOTEBOOK

# 加载数据
df = pd.read_csv('data.csv')

# 数据预处理：去除空格和转换数据类型
df['售价'] = df['售价'].astype(float)
df['单价'] = df['单价'].astype(float)
df['面积'] = df['面积'].astype(float)
df['楼层'] = df['楼层'].str.extract('(\d+)').astype(float)  # 提取楼层数字部分
#如果年份只年份的信息，如‘2014’就不用处理，若年份列包含"2014年"格式的信息，我们首先去掉非数字字符
df['年份'] = df['年份'].str.extract('(\d{4})')  # 提取四位数年份
df['年份'] = pd.to_datetime(df['年份'], format='%Y', errors='coerce').dt.year


# 查看数据前几行
df.head()
# Out:
#                            标题       小区    区域    售价      单价    户型     面积   朝向  \
# 0  铁道学院次新盘 高绿化 人车分流 总价低拎包入住一房  天鸿中央大院   铁道学院  29.9  8390.0  1室1厅  35.64    北
# 1     中上楼层，视野好，业主诚信出售 毛坯价买装修房  绿地香树花城    望城区  37.8  4819.0  2室1厅  78.45    南
# 2     火车站向韶村 单位房 分摊小 楼层好 独立院子  省地铁局宿舍    火车站  43.8  5848.0  2室1厅  74.90  南 北
# 3         麓谷公园一房一厅复式楼，公园旁地铁口！  金荣央谷金座    麓谷东  29.8  6483.0  1室1厅  45.97    南
# 4       小高层电梯房，一梯两户低密度，居住环境舒适   润芳园小区    东方红  75.0  8178.0  3室2厅  91.72    南
#
#    装修    楼层      年份  建筑类型                                                详情页
# 0  其他  34.0  2016.0    板楼  https://cs.lianjia.com/ershoufang/104113530626...
# 1  其他  34.0     NaN  板塔结合  https://cs.lianjia.com/ershoufang/104112311104...
# 2  简装   7.0     NaN  暂无数据  https://cs.lianjia.com/ershoufang/104113289418...
# 3  简装   5.0  2012.0    板楼  https://cs.lianjia.com/ershoufang/104111597568...
# 4  简装  17.0     NaN  板塔结合  https://cs.lianjia.com/ershoufang/104110468778...

# %%
from pyecharts import options as opts
from pyecharts.charts import Pie
from pyecharts.faker import Faker

c = (
    Pie()
    .add(
        "",
        [
            list(z)
            for z in zip(house_type, house_num)
        ],
        center=["40%", "50%"],
    )
    .set_global_opts(
        title_opts=opts.TitleOpts(title="二手房源户型分布"),
        legend_opts=opts.LegendOpts(type_="scroll", pos_left="80%", orient="vertical"),
    )
    .set_series_opts(label_opts=opts.LabelOpts(formatter="{b}: {c}"))
#     .render("pie_scroll_legend.html")
)
c.load_javascript()

# %%
c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/v5/echarts.min'
#         }
#     });
# </script>
#
#         <div id="49f6d664d2fe4dcb91f84d2371e70649" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_49f6d664d2fe4dcb91f84d2371e70649 = echarts.init(
#                     document.getElementById('49f6d664d2fe4dcb91f84d2371e70649'), 'white', {renderer: 'canvas'});
#                 var option_49f6d664d2fe4dcb91f84d2371e70649 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "aria": {
#         "enabled": false
#     },
#     "color": [
#         "#5470c6",
#         "#91cc75",
#         "#fac858",
# ...

# %%
face_type = df['朝向'].value_counts().index.to_list()
face_num = df['朝向'].value_counts().to_list()
c = (
    Pie()
    .add(
        "",
        [
            list(z)
            for z in zip(face_type, face_num)
        ],
        center=["40%", "50%"],
    )
    .set_global_opts(
        title_opts=opts.TitleOpts(title="二手房源朝向分布"),
        legend_opts=opts.LegendOpts(type_="scroll", pos_left="80%", orient="vertical"),
    )
    .set_series_opts(label_opts=opts.LabelOpts(formatter="{b}: {c}"))
#     .render("pie_scroll_legend.html")
)
c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/v5/echarts.min'
#         }
#     });
# </script>
#
#         <div id="158e6fccf0f341868ab56aa8968c96e9" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_158e6fccf0f341868ab56aa8968c96e9 = echarts.init(
#                     document.getElementById('158e6fccf0f341868ab56aa8968c96e9'), 'white', {renderer: 'canvas'});
#                 var option_158e6fccf0f341868ab56aa8968c96e9 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "aria": {
#         "enabled": false
#     },
#     "color": [
#         "#5470c6",
#         "#91cc75",
#         "#fac858",
# ...

# %%
face_type = df['装修'].value_counts().index.to_list()
face_num = df['装修'].value_counts().to_list()
c = (
    Pie()
    .add(
        "",
        [
            list(z)
            for z in zip(face_type, face_num)
        ],
        center=["40%", "50%"],
    )
    .set_global_opts(
        title_opts=opts.TitleOpts(title="二手房源装修分布"),
        legend_opts=opts.LegendOpts(type_="scroll", pos_left="80%", orient="vertical"),
    )
    .set_series_opts(label_opts=opts.LabelOpts(formatter="{b}: {c}"))
#     .render("pie_scroll_legend.html")
)
c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/v5/echarts.min'
#         }
#     });
# </script>
#
#         <div id="ac8dc5b8ade74f9b8ba8a17055721ae4" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_ac8dc5b8ade74f9b8ba8a17055721ae4 = echarts.init(
#                     document.getElementById('ac8dc5b8ade74f9b8ba8a17055721ae4'), 'white', {renderer: 'canvas'});
#                 var option_ac8dc5b8ade74f9b8ba8a17055721ae4 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "aria": {
#         "enabled": false
#     },
#     "color": [
#         "#5470c6",
#         "#91cc75",
#         "#fac858",
# ...

# %%
face_type = df['年份'].value_counts().index.to_list()
face_num = df['年份'].value_counts().to_list()
c = (
    Pie()
    .add(
        "",
        [
            list(z)
            for z in zip(face_type, face_num)
        ],
        center=["40%", "50%"],
    )
    .set_global_opts(
        title_opts=opts.TitleOpts(title="二手房源年份分布"),
        legend_opts=opts.LegendOpts(type_="scroll", pos_left="80%", orient="vertical"),
    )
    .set_series_opts(label_opts=opts.LabelOpts(formatter="{b}: {c}"))
#     .render("pie_scroll_legend.html")
)
c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/v5/echarts.min'
#         }
#     });
# </script>
#
#         <div id="fdefbd8732ec4244859ca84e26345b5c" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_fdefbd8732ec4244859ca84e26345b5c = echarts.init(
#                     document.getElementById('fdefbd8732ec4244859ca84e26345b5c'), 'white', {renderer: 'canvas'});
#                 var option_fdefbd8732ec4244859ca84e26345b5c = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "aria": {
#         "enabled": false
#     },
#     "color": [
#         "#5470c6",
#         "#91cc75",
#         "#fac858",
# ...

# %%
# 导入需要的库
from pyecharts.charts import Scatter

# 按面积分布统计房源数量
scatter_data = df[['面积', '售价']].values.tolist()

# 创建散点图
scatter = (
    Scatter()
    .add_xaxis(df['面积'].values.tolist())
    .add_yaxis("房源售价", df['售价'].values.tolist())
    .set_series_opts(label_opts=opts.LabelOpts(is_show=False))
    .set_global_opts(
        title_opts=opts.TitleOpts(title="房源面积与售价分布散点图"),
        xaxis_opts=opts.AxisOpts(type_="value", name="面积"),
        yaxis_opts=opts.AxisOpts(type_="value", name="售价"),
    )
)

# 显示散点图
scatter.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/v5/echarts.min'
#         }
#     });
# </script>
#
#         <div id="75615a0b110e4951ad06269fdf93cc72" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_75615a0b110e4951ad06269fdf93cc72 = echarts.init(
#                     document.getElementById('75615a0b110e4951ad06269fdf93cc72'), 'white', {renderer: 'canvas'});
#                 var option_75615a0b110e4951ad06269fdf93cc72 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "aria": {
#         "enabled": false
#     },
#     "color": [
#         "#5470c6",
#         "#91cc75",
#         "#fac858",
# ...

# %%
# 按建筑类型统计房源数量
building_type_counts = df['建筑类型'].value_counts()

# 创建柱状图
building_type_bar = (
    Bar()
    .add_xaxis(building_type_counts.index.tolist())
    .add_yaxis("房源数量", building_type_counts.values.tolist())
    .set_global_opts(
        title_opts=opts.TitleOpts(title="按建筑类型统计房源数量"),
        xaxis_opts=opts.AxisOpts(name="建筑类型"),
        yaxis_opts=opts.AxisOpts(name="房源数量")
    )
)

# 显示柱状图
building_type_bar.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/v5/echarts.min'
#         }
#     });
# </script>
#
#         <div id="c39bd696b3344f7d97f101f1963f9e1b" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_c39bd696b3344f7d97f101f1963f9e1b = echarts.init(
#                     document.getElementById('c39bd696b3344f7d97f101f1963f9e1b'), 'white', {renderer: 'canvas'});
#                 var option_c39bd696b3344f7d97f101f1963f9e1b = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "aria": {
#         "enabled": false
#     },
#     "color": [
#         "#5470c6",
#         "#91cc75",
#         "#fac858",
# ...

# %%
# 按单价统计房源数量
unit_price_counts = df['单价'].value_counts()

# 创建柱状图
unit_price_bar = (
    Bar()
    .add_xaxis(unit_price_counts.index.astype(str).tolist())
    .add_yaxis("房源数量", unit_price_counts.values.tolist())
    .set_global_opts(
        title_opts=opts.TitleOpts(title="按单价统计房源数量"),
        xaxis_opts=opts.AxisOpts(name="单价"),
        yaxis_opts=opts.AxisOpts(name="房源数量")
    )
)

# 显示柱状图
unit_price_bar.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/v5/echarts.min'
#         }
#     });
# </script>
#
#         <div id="d77b4c1faf9e4bf0b209dc2c096347b2" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_d77b4c1faf9e4bf0b209dc2c096347b2 = echarts.init(
#                     document.getElementById('d77b4c1faf9e4bf0b209dc2c096347b2'), 'white', {renderer: 'canvas'});
#                 var option_d77b4c1faf9e4bf0b209dc2c096347b2 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "aria": {
#         "enabled": false
#     },
#     "color": [
#         "#5470c6",
#         "#91cc75",
#         "#fac858",
# ...

# %%
# 导入配置项
from pyecharts import options as opts
# 导入饼图
from pyecharts.charts import Pie
# 随机生成数据模块
from pyecharts.faker import Faker
# 参数配置
c = (
    Pie()
    .add(
        "",
        [
            list(z)
            # 传入参数
            for z in zip(
                area_type,
                area_num,
            )
        ],
        center=["40%", "50%"],
    )
    .set_global_opts(
        # 标题
        title_opts=opts.TitleOpts(title="二手房源区域占比分布"),
        legend_opts=opts.LegendOpts(type_="scroll", pos_left="80%", orient="vertical"),
    )
    .set_series_opts(label_opts=opts.LabelOpts(formatter="{b}: {c}"))
    # 把可视化保存html文件
#     .render("pie_scroll_legend.html")
)
# print(Faker.choose())  #  ['可乐', '雪碧', '橙汁', '绿茶', '奶茶', '百威', '青岛'] 数据类目
# print(Faker.values()) # [139, 54, 136, 136, 52, 73, 85] 数据数量
# 可视化展示在jupyter上面
c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/v5/echarts.min'
#         }
#     });
# </script>
#
#         <div id="6dc67eb292a149bb88a808330b0f9aa6" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_6dc67eb292a149bb88a808330b0f9aa6 = echarts.init(
#                     document.getElementById('6dc67eb292a149bb88a808330b0f9aa6'), 'white', {renderer: 'canvas'});
#                 var option_6dc67eb292a149bb88a808330b0f9aa6 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "aria": {
#         "enabled": false
#     },
#     "color": [
#         "#5470c6",
#         "#91cc75",
#         "#fac858",
# ...

# %%
area_num = df['小区'].value_counts().to_list()[:10] # 统计数据个数
area_type = df['小区'].value_counts().index.to_list()[:10] # 统计数据类目

# %%
# 提取 '楼层' 列的值和计数
floor_type = df['楼层'].value_counts().index.to_list()
floor_num = df['楼层'].value_counts().to_list()

# 创建楼层分布的饼图
c = (
    Pie()
    .add(
        "",
        [list(z) for z in zip(floor_type, floor_num)],
        center=["40%", "50%"],
    )
    .set_global_opts(
        title_opts=opts.TitleOpts(title="二手房源楼层分布"),
        legend_opts=opts.LegendOpts(type_="scroll", pos_left="80%", orient="vertical"),
    )
    .set_series_opts(label_opts=opts.LabelOpts(formatter="{b}: {c}"))
)
c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/v5/echarts.min'
#         }
#     });
# </script>
#
#         <div id="4d807385ad4a43afbb80063135c51eaa" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_4d807385ad4a43afbb80063135c51eaa = echarts.init(
#                     document.getElementById('4d807385ad4a43afbb80063135c51eaa'), 'white', {renderer: 'canvas'});
#                 var option_4d807385ad4a43afbb80063135c51eaa = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "aria": {
#         "enabled": false
#     },
#     "color": [
#         "#5470c6",
#         "#91cc75",
#         "#fac858",
# ...

# %%
import pandas as pd
from pyecharts.charts import Line
from pyecharts import options as opts

# 加载数据
df = pd.read_csv('data.csv')

# 打印列名，确认列名
print(df.columns)

# 检查是否已经有 '年份' 列
if '年份' in df.columns:
    # 计算每年平均房价并保留一位小数
    yearly_price = df.groupby('年份')['售价'].mean().reset_index()
    yearly_price['售价'] = yearly_price['售价'].round(1)  # 保留一位小数
else:
    # 提取日期并创建 '年份' 列
    df['挂牌日期'] = pd.to_datetime(df['挂牌日期'], errors='coerce')
    df['年份'] = df['挂牌日期'].dt.year
    # 计算每年平均房价并保留一位小数
    yearly_price = df.groupby('年份')['售价'].mean().reset_index()
    yearly_price['售价'] = yearly_price['售价'].round(1)  # 保留一位小数

# 时序分析：绘制房价随年份的变化趋势
line = (
    Line()
    .add_xaxis(yearly_price['年份'].tolist())
    .add_yaxis("平均售价", yearly_price['售价'].tolist(), is_smooth=True)
    .set_global_opts(
        title_opts=opts.TitleOpts(title="房价随年份变化趋势"),
        xaxis_opts=opts.AxisOpts(type_="category", boundary_gap=False),
        yaxis_opts=opts.AxisOpts(type_="value"),
        tooltip_opts=opts.TooltipOpts(trigger="axis",
                                    formatter="{b}: {c}"  # 格式化提示框显示的数值
                                    ),
    )
)

line.render_notebook()
# Out:
# Index(['标题', '小区', '区域', '售价', '单价', '户型', '面积', '朝向', '装修', '楼层', '年份',
#        '建筑类型', '详情页'],
#       dtype='object')
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/v5/echarts.min'
#         }
#     });
# </script>
#
#         <div id="9bbbd7dff07646969a7304fbb64bf312" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_9bbbd7dff07646969a7304fbb64bf312 = echarts.init(
#                     document.getElementById('9bbbd7dff07646969a7304fbb64bf312'), 'white', {renderer: 'canvas'});
#                 var option_9bbbd7dff07646969a7304fbb64bf312 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "aria": {
# ...
